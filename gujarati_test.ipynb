# %%
EMBEDDING_MODEL =  "sampoorna42/Gujju-Llama-Instruct-v0.1"
TEXT_GENERATION_MODEL_REPO = "sampoorna42/Gujju-Llama-Instruct-v0.1"


import logging
import sys

logging.basicConfig(stream=sys.stdout, level=logging.INFO)
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))


import torch

torch.cuda.is_available()
print("DEVICE:", "GPU" if torch.cuda.is_available() else "CPU")


from llama_index.core import Settings
from llama_index.embeddings.huggingface import (
    HuggingFaceInferenceAPIEmbedding,
    HuggingFaceEmbedding,
)
from llama_index.llms.huggingface import HuggingFaceInferenceAPI, HuggingFaceLLM
from llama_index.core.node_parser import SentenceSplitter


# Settings.text_splitter = SentenceSplitter(chunk_size=1024, chunk_overlap=20)

# Settings.embed_model = HuggingFaceInferenceAPIEmbedding(model_name=EMBEDDING_MODEL)

#### Inference API
llm = HuggingFaceLLM(
    model_name=TEXT_GENERATION_MODEL_REPO,
    device_map="cuda:0",
    # token="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"
)
# Out:
# DEVICE: GPU
# Loading checkpoint shards:   0%|          | 0/3 [00:02<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[26], line 32
#      24 from llama_index.core.node_parser import SentenceSplitter
#      27 # Settings.text_splitter = SentenceSplitter(chunk_size=1024, chunk_overlap=20)
#      28
#      29 # Settings.embed_model = HuggingFaceInferenceAPIEmbedding(model_name=EMBEDDING_MODEL)
#      30
#      31 #### Inference API
# ---> 32 llm = HuggingFaceLLM(
#      33     model_name=TEXT_GENERATION_MODEL_REPO,
#      34     device_map="cuda:0",
#      35     # token="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"
#      36 )
#
# ...

# %%
llm.complete("નમસ્તે")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 llm.complete("નમસ્તે")
#
# File u:\Files\LamaIndex\.venv\lib\site-packages\llama_index\core\llms\callbacks.py:323, in llm_completion_callback.<locals>.wrap.<locals>.wrapped_llm_predict(_self, *args, **kwargs)
#     306 dispatcher.event(
#     307     LLMCompletionStartEvent(
#     308         model_dict=_self.to_dict(),
#    (...)
#     312     )
#     313 )
#     314 event_id = callback_manager.on_event_start(
#     315     CBEventType.LLM,
#     316     payload={
#    (...)
#     320     },
#     321 )
# --> 323 f_return_val = f(_self, *args, **kwargs)
#     324 if isinstance(f_return_val, Generator):
#     325     # intercept the generator and add a callback to the end
#     326     def wrapped_gen() -> CompletionResponseGen:
#
# ...
